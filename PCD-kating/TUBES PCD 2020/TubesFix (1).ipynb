# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
upload = files.upload()
for i in upload.keys():
  img = cv2.imread(i)
plt.imshow(img)
# Out:
#      <input type="file" id="files-a54664a0-8e31-477e-9d70-40fc08df34e7" name="files[]" multiple disabled />
#      <output id="result-a54664a0-8e31-477e-9d70-40fc08df34e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Y243.JPG to Y243.JPG

# %% [markdown]
# # GRAYSCALE

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")

# %%
# fungsi Pad untuk mengatasi masalah menggantung
def Pad(data, kernel):
    pad_upleft = (kernel - 1) // 2
    pad_downright = kernel // 2
    paddedCitra = np.pad(data, (pad_upleft, pad_downright), mode='constant')
    return paddedCitra
# fungsi untuk melakukan mean filter
def MeanFilter(data, kernel_size):
    padded = Pad(data,kernel_size)
    data_final = np.zeros(data.shape)
    rows, cols = data.shape
    for i in range(rows):
      for j in range(cols):
        mean = np.mean(padded[i:i+kernel_size, j:j+kernel_size])
        data_final[i][j] = mean
    # menampilkan data yang telah diproses filternya
    return data_final.astype('uint8')

# %% [markdown]
# # MEAN FILTER

# %%
filtered = MeanFilter(gray,5)
plt.imshow(filtered, cmap="gray")

# %% [markdown]
# Semakin besar kernel maka semakin blur

# %% [markdown]
# # INVERS

# %%
invers = 255 - filtered
#invers = cv2.bitwise_not(filtered)

plt.imshow(invers, cmap="gray")

# %% [markdown]
# # SUBTRACT

# %%
subtracted = cv2.subtract(gray,invers)
plt.imshow(subtracted, cmap="gray")

# %% [markdown]
# Semakin blur gambar yang di subtract maka semakin sedikit serpihan citra yang tidak dibutuhkan atau diinginkan

# %% [markdown]
# # THRESHOLDING

# %%
# mengambil nilai dari fungsi treshold incers
ret,thresh = cv2.threshold(subtracted,50,255,cv2.THRESH_BINARY)

# menampilkan gambar
plt.imshow(thresh, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# # EROSI

# %%
kernel = np.ones((5,5),dtype=int)

# %% [markdown]
# Semakin besar kernel maka hasil morfologi semakin berpengaruh. Lakukan iterasi tambahan jika hasil yang didapat belum maksimal

# %%
erosi = cv2.erode(thresh,kernel,iterations = 1)
plt.imshow(erosi, cmap="gray")

# %% [markdown]
# # OPENING

# %%
opening = cv2.dilate(erosi,kernel,iterations = 1)
plt.imshow(opening, cmap="gray")

# %% [markdown]
# # CONTOURS

# %%
contours, hierarchy = cv2.findContours(opening, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
contor = cv2.drawContours(img, contours, -1, (0, 255, 0), 2)
plt.imshow(contor, cmap="gray")

# %%
prepocessing = [gray, filtered, invers, subtracted, thresh, erosi, opening, contor]
titles = ['Grayscale', 'Filtered', 'Invers', 'Subtracted', 'Threshold', 'Eroded', 'Opened', "Detected"]
f = plt.figure()
for i in range(len(titles)):
    f.add_subplot(2, 4, i + 1)
    plt.imshow(prepocessing[i], cmap="gray")
    plt.title(titles[i])
    f.set_size_inches(np.array(f.get_size_inches())+0.5)
    plt.xticks([]), plt.yticks([])
plt.show()
